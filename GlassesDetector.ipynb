# %%
# !pip install opencv-python
# !pip install ultralytics
# Out:
# Requirement already satisfied: opencv-python in /home/phong/miniconda3/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/phong/miniconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: ultralytics in /home/phong/miniconda3/lib/python3.12/site-packages (8.3.34)
# Requirement already satisfied: numpy>=1.23.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from ultralytics) (2.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /home/phong/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/phong/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/phong/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/phong/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/phong/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/phong/miniconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/phong/miniconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/phong/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/phong/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/phong/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/phong/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: networkx in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: setuptools in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (68.2.2)
# Requirement already satisfied: sympy==1.13.1 in /home/phong/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /home/phong/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/phong/miniconda3/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)

# %%
import os
import cv2
from ultralytics import YOLO
import torch

# %%
if torch.cuda.is_available():
    print("CUDA khả dụng. Đang sử dụng GPU.")
else:
    print("CUDA không khả dụng. Đang sử dụng CPU.")
# Out:
# CUDA khả dụng. Đang sử dụng GPU.

# %%
def calculate_iou(box1, box2):
    box1 = torch.tensor(box1)
    box2 = torch.tensor(box2)
    x1 = torch.max(box1[0], box2[0])
    y1 = torch.max(box1[1], box2[1])
    x2 = torch.min(box1[2], box2[2])
    y2 = torch.min(box1[3], box2[3])

    # Diện tích phần giao nhau
    intersection_area = torch.clamp(x2 - x1, min=0) * torch.clamp(y2 - y1, min=0)

    # Diện tích bounding box
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])

    # Tính IoU
    iou = intersection_area / (box1_area + box2_area - intersection_area)
    return iou.item()
def filter_overlapping_boxes(bboxes_with_conf, overlap_threshold=0.3):
    bboxes_with_conf.sort(key=lambda x: x[4], reverse=True)  # Sắp xếp theo conf giảm dần
    filtered_bboxes = []

    for i, box1 in enumerate(bboxes_with_conf):
        keep = True
        for box2 in filtered_bboxes:
            overlap = calculate_iou(box1[:4], box2[:4])
            if overlap > overlap_threshold:
                keep = False
                break
        if keep:
            filtered_bboxes.append(box1)

    return filtered_bboxes

def check_glasses_position(glasses_box, keypoints):
    glasses_center_x = (glasses_box[0] + glasses_box[2]) / 2
    glasses_center_y = (glasses_box[1] + glasses_box[3]) / 2

    # Lấy tọa độ các keypoint
    nose_x, nose_y = keypoints[0]  # Mũi
    left_eye_x, left_eye_y = keypoints[1]  # Mắt trái
    right_eye_x, right_eye_y = keypoints[2]  # Mắt phải
    left_shoulder_x, left_shoulder_y = keypoints[5]  # Vai trái
    right_shoulder_x, right_shoulder_y = keypoints[6]  # Vai phải

    # Kiểm tra kính trên túi áo
    if (left_shoulder_y < glasses_center_y and
        left_shoulder_x > glasses_center_x > right_shoulder_x):
        return "Pocket"

    # Kiểm tra kính trên đầu
    head_top_y = (left_eye_y + right_eye_y) / 2 - 0.2 * abs(left_eye_y - right_eye_y)
    if glasses_center_y < head_top_y:
        return "Head"

    return "Wearing"

# %%
image_folder = 'Glasses'
output_folder = 'final_output'
os.makedirs(output_folder, exist_ok=True)

# Load mô hình
yolo_model = YOLO('yolov8x-world.pt')
yolo_model.set_classes(["glasses", "sunglasses"])
pose_model = YOLO('yolov8n-pose.pt')

# Lặp qua từng ảnh
for filename in os.listdir(image_folder):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(image_folder, filename)
        # Bước 1: Dò kính (bounding boxes cho kính)
        glass_results = yolo_model.predict(image_path)
        glasses_bboxes_with_conf = [
            box[:6] for box in glass_results[0].boxes.data.tolist()
        ]  # Tọa độ kính, độ tin cậy (conf), và class
        
        # Lọc các bb kính bị trùng lặp
        glasses_bboxes_with_conf = filter_overlapping_boxes(glasses_bboxes_with_conf)
        
        # Bước 2: Dò người (bounding boxes và keypoints)
        pose_results = pose_model.predict(image_path, conf=0.5)
        people_bboxes = [box[:4] for box in pose_results[0].boxes.data.tolist()]
        people_keypoints = pose_results[0].keypoints.xy if pose_results[0].keypoints is not None else []
        
        # Liên kết kính với người dựa trên IoU
        glasses_to_people = []
        for glass_box_with_conf in glasses_bboxes_with_conf:
            glass_box = glass_box_with_conf[:4]
            max_iou = 0
            assigned_person = None
            for person_idx, person_box in enumerate(people_bboxes):
                iou = calculate_iou(glass_box, person_box)
                if iou > max_iou:
                    max_iou = iou
                    assigned_person = person_idx
        
            # Đánh dấu kính với người tương ứng (nếu có)
            if assigned_person is not None:
                glasses_to_people.append((glass_box_with_conf, assigned_person))
        
        # Bước 3: Kiểm tra vị trí kính
        annotated_image = cv2.imread(image_path)
        height, width, _ = annotated_image.shape
        
        font_scale = min(width, height) / 1000  # Tỉ lệ chữ dựa trên kích thước ảnh
        font_thickness = max(1, int(font_scale * 2.5))  # Độ dày phông chữ
        
        for glass_box_with_conf, person_idx in glasses_to_people:
            glass_box = glass_box_with_conf[:4]
            conf = glass_box_with_conf[4]  # Độ tin cậy
            cls = "glasses" if int(glass_box_with_conf[5]) == 0 else "sunglasses"  # Class
            keypoints = people_keypoints[person_idx]
            position = check_glasses_position(glass_box, keypoints)
        
            # Annotate ảnh với vị trí kính, độ tin cậy và class
            x1, y1, x2, y2 = map(int, glass_box)
            text = f"{position}-{cls}-Conf:{conf:.2f}"
            cv2.rectangle(annotated_image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(annotated_image, text, (x1, y2 + 10), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0, 255, 0), font_thickness)
        
        # Lưu ảnh kết quả
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, annotated_image)
# Out:
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/5.png: 448x640 1 glasses, 59.1ms
# Speed: 4.4ms preprocess, 59.1ms inference, 35.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/5.png: 448x640 1 person, 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 9.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/4.png: 448x640 1 glasses, 1 sunglasses, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/4.png: 448x640 1 person, 6.3ms
# Speed: 1.3ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/9.png: 416x640 1 glasses, 50.8ms
# Speed: 1.7ms preprocess, 50.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/9.png: 416x640 1 person, 41.0ms
# Speed: 2.2ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/19.png: 640x640 1 glasses, 75.2ms
# Speed: 1.7ms preprocess, 75.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/19.png: 640x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/5_.png: 640x640 2 glassess, 74.6ms
# Speed: 1.9ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/5_.png: 640x640 1 person, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/2_.png: 640x640 1 sunglasses, 74.5ms
# Speed: 2.2ms preprocess, 74.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/2_.png: 640x640 1 person, 5.5ms
# Speed: 2.0ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/img_2.png: 352x640 4 glassess, 50.1ms
# Speed: 1.7ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/img_2.png: 352x640 4 persons, 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/21.png: 384x640 1 glasses, 1 sunglasses, 46.6ms
# Speed: 1.4ms preprocess, 46.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/21.png: 384x640 1 person, 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/11.png: 448x640 3 glassess, 50.8ms
# Speed: 1.9ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/11.png: 448x640 1 person, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/14.png: 640x640 1 glasses, 75.1ms
# Speed: 1.9ms preprocess, 75.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/14.png: 640x640 1 person, 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/2.png: 640x448 1 glasses, 52.1ms
# Speed: 1.6ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/2.png: 640x448 1 person, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/10.png: 640x448 1 glasses, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/10.png: 640x448 1 person, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/img.png: 640x640 1 glasses, 75.6ms
# Speed: 1.7ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/img.png: 640x640 2 persons, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/8.png: 640x448 1 glasses, 50.6ms
# Speed: 2.4ms preprocess, 50.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/8.png: 640x448 1 person, 5.9ms
# Speed: 1.7ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/13.png: 448x640 (no detections), 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/13.png: 448x640 1 person, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/4_.png: 640x640 1 glasses, 75.7ms
# Speed: 2.1ms preprocess, 75.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/4_.png: 640x640 1 person, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/7.png: 640x608 1 glasses, 72.4ms
# Speed: 2.2ms preprocess, 72.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/7.png: 640x608 1 person, 40.4ms
# Speed: 2.5ms preprocess, 40.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/18.png: 640x416 1 sunglasses, 52.2ms
# Speed: 1.5ms preprocess, 52.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/18.png: 640x416 1 person, 43.6ms
# Speed: 1.8ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/12.png: 448x640 (no detections), 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/12.png: 448x640 1 person, 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/16.png: 640x576 1 glasses, 70.4ms
# Speed: 1.7ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/16.png: 640x576 1 person, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/3.png: 640x448 1 glasses, 51.1ms
# Speed: 1.6ms preprocess, 51.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/3.png: 640x448 1 person, 6.1ms
# Speed: 1.4ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/17.png: 640x640 1 glasses, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/17.png: 640x640 1 person, 6.0ms
# Speed: 1.9ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/20.png: 384x640 (no detections), 43.7ms
# Speed: 2.1ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/20.png: 384x640 1 person, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/img_1.png: 640x640 5 glassess, 75.0ms
# Speed: 1.9ms preprocess, 75.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/img_1.png: 640x640 5 persons, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/1.png: 448x640 1 glasses, 51.3ms
# Speed: 2.0ms preprocess, 51.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/1.png: 448x640 2 persons, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/6.png: 640x640 1 glasses, 75.1ms
# Speed: 2.6ms preprocess, 75.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/6.png: 640x640 1 person, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/3_.png: 640x640 1 glasses, 74.5ms
# Speed: 2.4ms preprocess, 74.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/3_.png: 640x640 1 person, 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/1_.png: 640x640 1 glasses, 74.6ms
# Speed: 1.7ms preprocess, 74.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/1_.png: 640x640 1 person, 5.5ms
# Speed: 1.7ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/15.png: 640x640 1 glasses, 75.1ms
# Speed: 2.6ms preprocess, 75.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/phong/PycharmProjects/Glasses_Detetor/Glasses/15.png: 640x640 1 person, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
